# %%
import numpy as np
import pandas as pd
import os

import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
current_directory = os.getcwd()
current_directory
# Out:
# 'C:\\Users\\User'

# %%
mba=pd.read_csv('E:/DATA/Knime/For MRA Project/MBA/dataset_group.csv')
rfm=pd.read_excel('E:/DATA/Knime/For MRA Project/RFM?/Sales_Data1.xlsx')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[33], line 2
#       1 mba=pd.read_csv('E:/DATA/Knime/For MRA Project/MBA/dataset_group.csv')
# ----> 2 rfm=pd.read_excel('E:/DATA/Knime/For MRA Project/RFM?/Sales_Data1.xlsx')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
# ...

# %%
rfm=pd.read_excel('E:/DATA/Knime/For MRA Project/RFM/Data/Sales_Data1.xlsx',sheet_name='Data')

# %%
rfm
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 0           10417               66     113.88                2   7516.08
# 1           10424               50     240.02                6  12001.00
# 2           10403               24     101.44                7   2434.56
# 3           10411               23     180.01                9   4140.23
# 4           10417               45     130.83                5   5887.35
# ...           ...              ...        ...              ...       ...
# 2742        10105               22     116.19                7   2556.18
# 2743        10117               50      43.68                2   2184.00
# 2744        10106               48      61.44               10   2949.12
# 2745        10106               48      52.64               15   2526.72
# 2746        10105               25      56.78                8   1419.50
#
#       ORDERDATE  DAYS_SINCE_LASTORDER      STATUS   PRODUCTLINE  MSRP  \
# ...

# %%
#finding the nulls
print('nulls in rfm set is',rfm.isnull().sum().sum())
print('nulls in mba set is',mba.isnull().sum().sum())
# Out:
# nulls in rfm set is 4
# nulls in mba set is 0

# %%
print('duplicates in rfm set is',rfm.duplicated().sum())
print('duplicates in mba set is',mba.duplicated().sum())
# Out:
# duplicates in rfm set is 1
# duplicates in mba set is 4730

# %%
mba[mba.duplicated()]
# Out:
#              Date  Order_id        Product
# 10     01-01-2018         1   all- purpose
# 13     01-01-2018         1   all- purpose
# 18     01-01-2018         1   dinner rolls
# 29     01-01-2018         2        waffles
# 31     01-01-2018         2      hand soap
# ...           ...       ...            ...
# 20616  24-02-2020      1137   paper towels
# 20632  25-02-2020      1138  sandwich bags
# 20633  25-02-2020      1138   toilet paper
# 20635  25-02-2020      1138           soda
# 20636  25-02-2020      1138           soda
#
# [4730 rows x 3 columns]

# %%
data=mba.groupby('Product').agg({'Order_id':'nunique','Date':'first'}).sort_values(by='Order_id',ascending=False)

# %%
data.reset_index()['Product'].nunique()
# Out:
# 37

# %% [raw]
# ****We are not treating the duplicates based on the assumption that the customer is purchasing more than one item which has been formated in a way that it appears as Duplicates.
#
# ***The dataset contains no null values.

# %%
#creating a new dataframe where all the products puchased per order Id is seggregated and grouped by the order_id which is unique
new_d =mba.groupby('Order_id',as_index=True).agg({'Product' : ', ' .join,'Date': 'first'})

# %%
new_d

# %%
print('The number of unique orders is',new_d.shape[0])
print('Nulls in Data set is',mba.isnull().sum().sum())
print('Duplicates in mba set is',mba.duplicated().sum())
print('Duplicates in mba set is',new_d.duplicated().sum())
print('The number of Unique products are',data.reset_index()['Product'].nunique())
# Out:
# The number of unique orders is 1139
# Nulls in Data set is 0
# Duplicates in mba set is 4730
# Duplicates in mba set is 0
# The number of Unique products are 37

# %%
mba.duplicated()

# %%
new_d
# Out:
#                                                     Product        Date
# Order_id
# 1         yogurt, pork, sandwich bags, lunch meat, all- ...  01-01-2018
# 2         toilet paper, shampoo, hand soap, waffles, che...  01-01-2018
# 3         soda, pork, soap, ice cream, toilet paper, din...  02-01-2018
# 4         cereals, juice, lunch meat, soda, toilet paper...  02-01-2018
# 5         sandwich loaves, pasta, tortillas, mixes, hand...  02-01-2018
# ...                                                     ...         ...
# 1135      sugar, beef, sandwich bags, hand soap, paper t...  22-02-2020
# 1136      coffee/tea, dinner rolls, lunch meat, spaghett...  23-02-2020
# 1137      beef, lunch meat, eggs, poultry, tortillas, be...  24-02-2020
# 1138      sandwich bags, ketchup, milk, poultry, cheeses...  25-02-2020
# 1139                       soda, laundry detergent, shampoo  26-02-2020
#
# [1139 rows x 2 columns]

# %%
rfm.isnull().sum().sum()
# Out:
# 4

# %%
rfm.isnull()
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3
# 0          True        True        True        True
# 1         False       False       False       False
# 2         False       False       False       False
# 3         False       False       False       False
# 4         False       False       False       False
# ..          ...         ...         ...         ...
# 329       False       False       False       False
# 330       False       False       False       False
# 331       False       False       False       False
# 332       False       False       False       False
# 333       False       False       False       False
#
# [334 rows x 4 columns]

# %%
#finding the nulls
print('nulls in rfm set is',rfm.isnull().sum().sum())
print('nulls in mba set is',mba.isnull().sum().sum())
# Out:
# nulls in rfm set is 4
# nulls in mba set is 0

# %%
print('Nulls in Data set is',rfm.isnull().sum().sum())
print('Duplicates in RFM Data set is',rfm.duplicated().sum())
print('Shape of the Dataset for RFM is',rfm.shape)
# Out:
# Nulls in Data set is 0
# Duplicates in RFM Data set is 0
# Shape of the Dataset for RFM is (2747, 20)

# %%
print('The number of Orderids available to us is', rfm.shape[0])
print('No of Data points available were',rfm.shape[1])
print('The no of data points available',rfm.size)
# Out:
# The number of Orderids available to us is 2747
# No of Data points available were 20
# The no of data points available 54940
